# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

plt.style.use('fivethirtyeight')
pd.set_option('max_columns',100)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[1], line 7
#       4 import plotly.express as px
#       6 plt.style.use('fivethirtyeight')
# ----> 7 pd.set_option('max_columns',100)
#
# File ~/.local/lib/python3.10/site-packages/pandas/_config/config.py:274, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     273 def __call__(self, *args, **kwds) -> T:
# --> 274     return self.__func__(*args, **kwds)
#
# File ~/.local/lib/python3.10/site-packages/pandas/_config/config.py:167, in _set_option(*args, **kwargs)
#     164     raise TypeError(f'_set_option() got an unexpected keyword argument "{kwarg}"')
#     166 for k, v in zip(args[::2], args[1::2]):
# --> 167     key = _get_single_key(k, silent)
#     169     o = _get_registered_option(key)
#     170     if o and o.validator:
#
# ...

# %%
from fredapi import Fred

# %%
import os
from dotenv import load_dotenv
load_dotenv()
fred_api = os.getenv('FRED_API')

# %% [markdown]
# Create Fred Object

# %%
fred=Fred(api_key=fred_api)

# %%
fred.search('S&P',order_by='popularity')
# Out:
#                                 id realtime_start realtime_end  \
# series id
# BAMLH0A0HYM2          BAMLH0A0HYM2     2024-08-01   2024-08-01
# CSUSHPINSA              CSUSHPINSA     2024-08-01   2024-08-01
# SP500                        SP500     2024-08-01   2024-08-01
# MEHOINUSA672N        MEHOINUSA672N     2024-08-01   2024-08-01
# BAMLH0A0HYM2EY      BAMLH0A0HYM2EY     2024-08-01   2024-08-01
# ...                            ...            ...          ...
# DDDI12SMA156NWDB  DDDI12SMA156NWDB     2024-08-01   2024-08-01
# DDDI01GTA156NWDB  DDDI01GTA156NWDB     2024-08-01   2024-08-01
# Q03069USQ605NNBR  Q03069USQ605NNBR     2024-08-01   2024-08-01
# CSHXCPVEA156NRUG  CSHXCPVEA156NRUG     2024-08-01   2024-08-01
# CSHMCPNPA156NRUG  CSHMCPNPA156NRUG     2024-08-01   2024-08-01
#
#                                                               title  \
# series id
# BAMLH0A0HYM2      ICE BofA US High Yield Index Option-Adjusted S...
# ...

# %%
sp_500=fred.get_series('SP500')

# %%
sp_500.plot(figsize=(12,6),title='SP 500',lw=1.5)
# Out:
# <Axes: title={'center': 'SP 500'}>

# %% [markdown]
# ## Pull multi Data series

# %%
unemployment=fred.search('unemployment')

# %%
df_unrate=fred.get_series('UNRATE')

# %%
df_unrate
# Out:
# 1948-01-01    3.4
# 1948-02-01    3.8
# 1948-03-01    4.0
# 1948-04-01    3.9
# 1948-05-01    3.5
#              ...
# 2024-02-01    3.9
# 2024-03-01    3.8
# 2024-04-01    3.9
# 2024-05-01    4.0
# 2024-06-01    4.1
# Length: 918, dtype: float64

# %%
df_unrate.plot(figsize=(10,6),title='UNRATE',lw=1.5)
# Out:
# <Axes: title={'center': 'UNRATE'}>
